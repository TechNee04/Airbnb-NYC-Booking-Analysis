# %% [markdown]
# # **Project Name - Airbnb NYC Bookings Analysis**

# %% [markdown]
# ### **Project Type - Exploratory Data Analysis (EDA)**
# ### **Name - Neelam Singh**

# %% [markdown]
# # The purpose of the analysis
# Understanding the factors that influence Airbnb prices in New York City, or identifying patterns of all variables and Our analysis provides useful information for travelers and hosts in the city and also provides some best insights for Airbnb business.

# %% [markdown]
# ## **Introduction of Airbnb**
# *	Airbnb is a popular online platform that allows individuals to list, discover, and book unique accommodations around the world. It was founded in 2008 by Brian Chesky, Joe Gebbia and Nathan Blecharczyk, and has since become the largest and most successful home-sharing companies in the world.
# *	Airbnb allows hosts to list their homes, apartments, or other properties for short-term rentals, and provides a platform for travelers to search for and book these accommodations. The platform includes a variety of listing types, including entire homes, private rooms, and shared rooms, and offers a wide range of price points to suit different budgets.
# *	Airbnb has also become a popular choice for travelers who want to experience a destination like a local, rather than as a tourist. With more than four million listings in over 100,000 cities.

# %% [markdown]
# ## **About the Dataset – AIRBNB BOOKINGS**
# ### Dataset Information
# *	Number of instances: 48895
# *	Number of attributes: 16
# *	The Data includes both categorical and numeric values, providing a diverse range of information about the listings.
# *	This Dataset may be useful for analyzing trends and patterns in the Airbnb market in New York and also gain insights into the preferences and behavior of Airbnb users in the area.
# *	This dataset contains information about Airbnb bookings in New York City in 2019. By analyzing this data, you may be able to understand the trends and patterns of Airbnb use in the NYC.

# %% [markdown]
# ## Understand the given variables

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Different Python libraries used to complete this EDA
# *	Pandas
# *	NumPy
# *	Matplotlib.Pyplot
# *	Seaborn

# %% [markdown]
# ## **Project Work flow**
# 1.	Importing Libraries
# 2.	Loading the Dataset
# 3.	explore Dataset
# 3.	Data Cleaning and manipulate
# 4.	Handling Outliers
# 5.	Data Visualization
# 6.	Conclusion

# %% [markdown]
# # **Problem Statements -**

# %% [markdown]
# PROBLEM STATEMENTS FOR ANALYSIS
#
# ![image.png](data:image/png;base64,...)

# %%
from google.colab import files
from IPython.display import Image
upload=files.upload()

# %%
Image('5891274 (1).jpg',width=1200)

# %% [markdown]
# # **Let's Dive in !**

# %% [markdown]
# ### **Importing the necessary libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Load Airbnb Dataset**

# %%
Airbnb_df = pd.read_csv('/content/drive/MyDrive/Project/Airbnb_ NYC.csv')
Airbnb_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# # **Data Exploration and Data Cleaning**

# %%
#exploring the column names
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# Renaming few column names for clarity

# %%
rename_col = {'id':'listing_id','name':'listing_name','number_of_reviews':'total_reviews','calculated_host_listings_count':'host_listings_count'}

# %%
# use a pandas function to rename the current function
Airbnb_df = Airbnb_df.rename(columns = rename_col)
Airbnb_df.head(2)
# Out:
#    listing_id                        listing_name  host_id host_name  \
# 0        2539  Clean & quiet apt home by the park     2787      John
# 1        2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  total_reviews last_review  reviews_per_month  \
# 0    149               1              9  2018-10-19               0.21
# 1    225               1             45  2019-05-21               0.38
#
#    host_listings_count  availability_365
# 0                    6               365
# 1                    2               355

# %%
#checking shape of Airbnb dataset
Airbnb_df.shape
# Out:
# (48895, 16)

# %%
#basic information about the dataset
Airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   listing_id           48895 non-null  int64
#  1   listing_name         48879 non-null  object
#  2   host_id              48895 non-null  int64
#  3   host_name            48874 non-null  object
#  4   neighbourhood_group  48895 non-null  object
#  5   neighbourhood        48895 non-null  object
#  6   latitude             48895 non-null  float64
#  7   longitude            48895 non-null  float64
#  8   room_type            48895 non-null  object
#  9   price                48895 non-null  int64
#  10  minimum_nights       48895 non-null  int64
#  11  total_reviews        48895 non-null  int64
#  12  last_review          38843 non-null  object
#  13  reviews_per_month    38843 non-null  float64
#  14  host_listings_count  48895 non-null  int64
# ...

# %% [markdown]
# Please note Last review is marked as categorical variable however it is a date column.Hence we will transform this to datetime data type.

# %% [markdown]
# **So, listing_name,host_name, neighbourhood_group, neighbourhood and room_type fall into categorical variable category.**
#
# **While host_id, latitude, longitude, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, host_listings_count, availability_365 are numerical variables.**
# **Please note Last review is marked as categorical variable however it is a date column.We will handle the same subsequently.**
#
# ---

# %%
# check duplicate rows in dataset
Airbnb_df = Airbnb_df.drop_duplicates()
Airbnb_df.count()
# Out:
# listing_id             48895
# listing_name           48879
# host_id                48895
# host_name              48874
# neighbourhood_group    48895
# neighbourhood          48895
# latitude               48895
# longitude              48895
# room_type              48895
# price                  48895
# minimum_nights         48895
# total_reviews          48895
# last_review            38843
# reviews_per_month      38843
# host_listings_count    48895
# availability_365       48895
# dtype: int64

# %% [markdown]
# **so, there are no  duplicate rows in Dataset**
#
# ---

# %%
# checking null values of each columns
Airbnb_df.isnull().sum()
# Out:
# listing_id                 0
# listing_name              16
# host_id                    0
# host_name                 21
# neighbourhood_group        0
# neighbourhood              0
# latitude                   0
# longitude                  0
# room_type                  0
# price                      0
# minimum_nights             0
# total_reviews              0
# last_review            10052
# reviews_per_month      10052
# host_listings_count        0
# availability_365           0
# dtype: int64

# %% [markdown]
# **host_name** and **listing_name** are not that much of null values, so first  we are good to fill those with some substitutes in both the columns first.

# %%
Airbnb_df['listing_name'].fillna('unknown',inplace=True)
Airbnb_df['host_name'].fillna('no_name',inplace=True)

# %%
#so the null values are removed
Airbnb_df[['host_name','listing_name']].isnull().sum()
# Out:
# host_name       0
# listing_name    0
# dtype: int64

# %% [markdown]
# now, the columns **last_review** and **reviews_per_month** have total 10052 null values each.
#
# **last_review** column is not required for our analysis as compared to **number_of_reviews** & **reviews_per_month**. We're good to drop this column.
#
# **listing_id** also not that important for our analysis but i won't remove because  **listing_id** and **listing_name** is a pair and removing listing_id still won't make much difference.I think this makes sense.

# %%
Airbnb_df = Airbnb_df.drop(['last_review'], axis=1)     #removing last_review column

# %%
Airbnb_df.info()      # the last_review column is deleted
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48895 entries, 0 to 48894
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   listing_id           48895 non-null  int64
#  1   listing_name         48895 non-null  object
#  2   host_id              48895 non-null  int64
#  3   host_name            48895 non-null  object
#  4   neighbourhood_group  48895 non-null  object
#  5   neighbourhood        48895 non-null  object
#  6   latitude             48895 non-null  float64
#  7   longitude            48895 non-null  float64
#  8   room_type            48895 non-null  object
#  9   price                48895 non-null  int64
#  10  minimum_nights       48895 non-null  int64
#  11  total_reviews        48895 non-null  int64
#  12  reviews_per_month    38843 non-null  float64
#  13  host_listings_count  48895 non-null  int64
#  14  availability_365     48895 non-null  int64
# ...

# %% [markdown]
# The **reviews_per_month** column also contains null values and we can replace it by 0 reviews

# %%
Airbnb_df['reviews_per_month'] = Airbnb_df['reviews_per_month'].replace(to_replace=np.nan,value=0).astype('int64')

# %%
# the null values are replaced by 0 value
Airbnb_df['reviews_per_month'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ---
#
# # **Describe the Dataset and removing outliers**

# %%
# describe the DataFrame
Airbnb_df.describe()
# Out:
#          listing_id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  total_reviews  reviews_per_month  host_listings_count  \
# count    48895.000000   48895.000000       48895.000000         48895.000000
# mean         7.029962      23.274466           0.806258             7.143982
# ...

# %%
sns.boxplot(x = Airbnb_df['price'])

plt.show()

# %%
# Cap the outliers in the 'price' column using IQR technique
q1 =  Airbnb_df['price'].quantile(0.25)
q3 =  Airbnb_df['price'].quantile(0.75)
iqr = q3 - q1
upper_threshold = q3 + 1.5 * iqr
lower_threshold = q1 - 1.5 * iqr
Airbnb_df['price'] = Airbnb_df['price'].clip(lower=lower_threshold, upper=upper_threshold)

# %%
sns.boxplot(x = Airbnb_df['price'])
print(Airbnb_df.shape)
# Out:
# (48895, 15)

# %% [markdown]
# ---
#
# # **Data Visualization**

# %% [markdown]
#    **(1)  Find distribution of Airbnb Bookings Price Range**

# %%
# Create a figure with a custom size
plt.figure(figsize=(12, 5))

# Set the seaborn theme to darkgrid
sns.set_theme(style='darkgrid')

# Create a histogram of the 'price' column of the Airbnb_df dataframe
# using sns distplot function and specifying the color as red
sns.distplot(Airbnb_df['price'],color=('r'))

# Add labels to the x-axis and y-axis
plt.xlabel('Price', fontsize=14)
plt.ylabel('Density', fontsize=14)

# Add a title to the plot
plt.title('Distribution of Airbnb Prices',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Distribution of Airbnb Prices')

# %% [markdown]
# **observations**
#
# *  We see that the distribution is positively skewed as majority concentration of price is towards the left and relatively fewer extremely high values to the right.The range of prices being charged on Airbnb appears to be from **20 to 330 dollars** , with the majority of listings falling in the price range of **50 to 150 dollars.**
#
# ---

# %% [markdown]
# ---
#
#
#    **(2) Find total listing/property count in each neighborhood group in NYC**

# %%
#Visualizing using countplot
sns.countplot(x="neighbourhood_group",data=df,order = Airbnb_df['neighbourhood_group'].value_counts().index)
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='count'>

# %%
# Count the number of listings in each neighborhood group and store the result in a Pandas series
counts = Airbnb_df['neighbourhood_group'].value_counts()

# Reset the index of the series so that the neighborhood groups become columns in the resulting dataframe
Top_Neighborhood_group = counts.reset_index()

# Rename the columns of the dataframe to be more descriptive
Top_Neighborhood_group.columns = ['Neighborhood_Groups', 'Listing_Counts']

# display the resulting DataFrame
Top_Neighborhood_group
# Out:
#   Neighborhood_Groups  Listing_Counts
# 0           Manhattan           19501
# 1            Brooklyn           19415
# 2              Queens            5567
# 3               Bronx            1070
# 4       Staten Island             365

# %% [markdown]
# **Observations**
#
# Listing Counts by Neighborhood Groups:
#
# Manhattan: It has the highest number of Airbnb listings among all the neighborhood groups, with 19,501 listings. This is indicative of Manhattan's popularity as a location for Airbnb accommodations.
#
# Brooklyn: Very close to Manhattan, Brooklyn follows with 19,415 listings. Brooklyn is also a highly sought-after area for Airbnb stays.
#
# Queens: Queens has a significant number of listings, but it is notably lower than Manhattan and Brooklyn, with 5,567 listings. This suggests that Queens is a popular but somewhat less saturated market for Airbnb accommodations.
#
# Bronx: The Bronx has a lower number of listings compared to Manhattan, Brooklyn, and Queens, with 1,070 listings. It may be perceived as a less common choice for Airbnb stays.
#
# Staten Island: Staten Island has the fewest listings among the neighborhood groups, with 365. This indicates that it might be the least popular or less frequently chosen neighborhood group for Airbnb accommodations.
#
# Overall Ranking:
#
# The overall ranking of neighborhood groups, based on listing counts from highest to lowest, is Manhattan, Brooklyn, Queens, Bronx, and Staten Island.
# Implications for Travelers and Hosts:
#
# Travelers looking for a wide range of options and experiences may find Manhattan and Brooklyn to be popular and diverse choices.
#
# Hosts in Manhattan and Brooklyn may face more competition due to the higher number of listings, while hosts in Queens, Bronx, and Staten Island may have a comparatively less competitive environment.
#
# Market Trends:
#
# The distribution of listing counts across neighborhood groups provides insights into the popularity and demand for Airbnb accommodations in different areas of the city.
#
#
#
#
#
#
#
# ---

# %% [markdown]
# ---
#
# **(3) Find Average Price Of listings/property in each Neighborhood Groups and also Neighborhood**

# %%
# Group by 'Neighborhood_Groups' and 'Neighborhood' and calculate the average price for each neighborhood
average_price_by_neighborhood = Airbnb_df.groupby(['neighbourhood_group', 'neighbourhood'])['price'].mean().reset_index()

# Display the average price by neighborhood
print("\nAverage Price by Neighborhood:")
average_price_by_neighborhood
# Out:
# Average Price by Neighborhood:
#     neighbourhood_group  neighbourhood       price
# 0                 Bronx       Allerton   78.756098
# 1                 Bronx     Baychester   75.428571
# 2                 Bronx        Belmont   77.125000
# 3                 Bronx      Bronxdale   57.105263
# 4                 Bronx    Castle Hill   63.000000
# ..                  ...            ...         ...
# 214       Staten Island  Tompkinsville   76.190476
# 215       Staten Island    Tottenville  144.857143
# 216       Staten Island  West Brighton   80.555556
# 217       Staten Island    Westerleigh   71.500000
# 218       Staten Island    Willowbrook  249.000000
#
# [219 rows x 3 columns]

# %%
# Group by 'neighbourhood_group' and calculate the average price for each group
average_price_by_group = Airbnb_df.groupby('neighbourhood_group')['price'].mean()

# Group by 'neighbourhood_group' and 'neighbourhood' and calculate the average price for each neighborhood
average_price_by_neighborhood = Airbnb_df.groupby(['neighbourhood_group', 'neighbourhood'])['price'].mean().reset_index()

# Choose a subset of neighborhoods for visualization (e.g., top 10)
top_neighborhoods = average_price_by_neighborhood.groupby('neighbourhood_group').apply(lambda x: x.nlargest(10, 'price')).reset_index(drop=True)

# Set the seaborn theme
sns.set_theme(style='whitegrid')

# Create a bar plot for average price by neighborhood
plt.figure(figsize=(18, 8))
sns.barplot(x='neighbourhood', y='price', hue='neighbourhood_group', data=top_neighborhoods, palette='viridis')

# Add labels and title
plt.xlabel('Neighborhood', fontsize=14)
plt.ylabel('Average Price', fontsize=14)
plt.title('Average Price by Neighborhood (Top 10)', fontsize=16)
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability

# Show the plot
plt.show()

# %% [markdown]
# From the above plot it can be inferred that among the top 10 neighbourhoods and neighbourhood groups, Staten island has the highest average price followed by Queens,Manhattan,Brooklyn and Bronx.

# %% [markdown]
# Now lets analyse both Neighborhood and Neighborhood group separately

# %%
print('Average Price Of listings/property in each Neighborhood Groups are :')
df1 = Airbnb_df.groupby(["neighbourhood_group"])["price"].mean().sort_values(ascending=False).head()
df1.plot(kind='bar')
plt.show()
pd.DataFrame(df1)
# Out:
# Average Price Of listings/property in each Neighborhood Groups are :
#                           price
# neighbourhood_group
# Manhattan            145.904620
# Brooklyn             105.699614
# Staten Island         89.235616
# Queens                88.904437
# Bronx                 77.365421

# %%
print('Average Price Of listings/property in each Neighborhood  are :')
df2 = Airbnb_df.groupby(["neighbourhood"])["price"].mean().sort_values(ascending=False).head(15)
df2.plot(kind='bar')
plt.show()
pd.DataFrame(df2)
# Out:
# Average Price Of listings/property in each Neighborhood  are :
#                          price
# neighbourhood
# Willowbrook         249.000000
# Neponsit            237.000000
# Breezy Point        213.333333
# Tribeca             212.495327
# NoHo                205.290909
# West Village        192.901235
# Flatiron District   188.090909
# Financial District  183.973926
# Midtown             180.948381
# Greenwich Village   179.853372
# Mill Basin          179.750000
# Murray Hill         179.559719
# Chelsea             178.653319
# Theater District    176.380165
# DUMBO               174.750000

# %% [markdown]
# **Observations >**
#
# *   The average price of a listing in New York City varies significantly across different neighborhoods, with **Manhattan having the highest 146 dollars/day  average price** and **the Bronx having the lowest near 77 dollars/day.**
#
# *   The average price increases as you move from the outer boroughs (Bronx, Brooklyn, Queens, and Staten Island) towards the center of the city (Manhattan).
#
# *   The average price in queens and Staten Island is relatively similar, despite being in different parts of the city.
#
# *   The data suggests that the overall cost of living in New York City is higher in the center of the city (Manhattan) compared to the outer boroughs. This is likely due to the fact that Manhattan is the most densely populated and commercially important borough, and therefore has higher demand for housing in the centrally located neighborhoods.

# %% [markdown]
# ---
#
# **(4) Top Neighborhoods and Hosts by Listing/Property in entire NYC**

# %%
top_neighborhoods = Airbnb_df['neighbourhood'].value_counts().head(10)

plt.figure(figsize=(12, 6))
sns.barplot(x=top_neighborhoods.index, y=top_neighborhoods.values, palette='viridis')
plt.title('Top Neighborhoods in NYC by Listing Count')
plt.xlabel('Neighborhood')
plt.ylabel('Listing Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# create a new DataFrame that displays the top 10 neighborhoods in the Airbnb NYC dataset based on the number of listings in each neighborhood
Top_Neighborhoods = Airbnb_df['neighbourhood'].value_counts()[:10].reset_index()

# rename the columns of the resulting DataFrame to 'Top_Neighborhoods' and 'Listing_Counts'
Top_Neighborhoods.columns = ['Top_Neighborhoods', 'Listing_Counts']

# display the resulting DataFrame
Top_Neighborhoods
# Out:
#     Top_Neighborhoods  Listing_Counts
# 0        Williamsburg            3732
# 1  Bedford-Stuyvesant            3638
# 2              Harlem            2585
# 3            Bushwick            2438
# 4     Upper West Side            1788
# 5      Hell's Kitchen            1731
# 6        East Village            1714
# 7     Upper East Side            1670
# 8       Crown Heights            1519
# 9             Midtown            1143

# %%
top_hosts = Airbnb_df['host_name'].value_counts().head(10)

plt.figure(figsize=(12, 6))
sns.barplot(x=top_hosts.index, y=top_hosts.values, palette='viridis')
plt.title('Top Hosts in NYC by Listing Count')
plt.xlabel('Host Name')
plt.ylabel('Listing Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# Observations -->
#
# The top three hosts in terms of total listings are Michael, David, and John, who have 383, 368, and 276 listings, respectively.
#
# There is a relatively large gap between the top two hosts and the rest of the hosts. For example, john has 276 listings, which is significantly fewer than Michael's 383 listings.
#
# In this top10 list Mike has 184 listings, which is significantly fewer than Michael's 383 listings. This could indicate that there is a lot of variation in the success of different hosts on Airbnb.
#
# There are relatively few hosts with a large number of listings. This could indicate that the Airbnb market is relatively competitive, with a small number of hosts dominating a large portion of the market.
#
# ---

# %% [markdown]
# ---
# **(5)Find the Number of Active Hosts Per Location by Each Neighborhood Groups**

# %%
# create a new DataFrame that displays the number of hosts in each neighborhood group in the Airbnb NYC dataset
hosts_per_location = Airbnb_df.groupby(['neighbourhood_group', 'neighbourhood'])['host_id'].count().reset_index()

# rename the columns of the resulting DataFrame to 'Neighbourhood_Groups' and 'Host_counts'
hosts_per_location.columns = ['Neighbourhood_Groups', 'Neighbourhood','Count_of_hosts']

# display the resulting DataFrame
hosts_per_location
# Out:
#     Neighbourhood_Groups  Neighbourhood  Count_of_hosts
# 0                  Bronx       Allerton              42
# 1                  Bronx     Baychester               7
# 2                  Bronx        Belmont              24
# 3                  Bronx      Bronxdale              19
# 4                  Bronx    Castle Hill               9
# ..                   ...            ...             ...
# 216        Staten Island    Tottenville               7
# 217        Staten Island  West Brighton              18
# 218        Staten Island    Westerleigh               2
# 219        Staten Island    Willowbrook               1
# 220        Staten Island        Woodrow               1
#
# [221 rows x 3 columns]

# %%
another_group = hosts_per_location.groupby('Neighbourhood_Groups')['Count_of_hosts'].max().reset_index()
another_group
# Out:
#   Neighbourhood_Groups  Count_of_hosts
# 0                Bronx              70
# 1             Brooklyn            3920
# 2            Manhattan            2658
# 3               Queens             900
# 4        Staten Island              48

# %%
host_df =hosts_per_location.merge(another_group, how = 'inner', on = ['Neighbourhood_Groups', 'Count_of_hosts'])
host_df
# Out:
#   Neighbourhood_Groups Neighbourhood  Count_of_hosts
# 0                Bronx   Kingsbridge              70
# 1             Brooklyn  Williamsburg            3920
# 2            Manhattan        Harlem            2658
# 3               Queens       Astoria             900
# 4        Staten Island    St. George              48

# %%
# Set the seaborn theme
sns.set_theme(style='whitegrid')

# Create a bar plot
plt.figure(figsize=(10, 8))
sns.barplot(x='Neighbourhood', y='Count_of_hosts', hue='Neighbourhood_Groups', data=host_df, palette='viridis')
plt.xlabel('Neighborhood', fontsize=14)
plt.ylabel('Count_of_hosts', fontsize=14)
plt.title('Count of Hosts in Different Neighbourhoods by Neighbourhood Group')
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
# Group the data by neighbourhood_group and count the number of listings for each group
hosts_per_location = Airbnb_df.groupby('neighbourhood_group')['listing_id'].count()

# Get the list of neighbourhood_group names
locations = hosts_per_location.index

# Get the list of host counts for each neighbourhood_group
host_counts = hosts_per_location.values
# Set the figure size
plt.figure(figsize=(12, 5))

# Create a horizontal bar chart
plt.barh(locations, host_counts, color=['skyblue', 'lightcoral', 'lightgreen', 'gold', 'lightcyan'])

# Add a title and labels to the x-axis and y-axis
plt.title('Number of Active Hosts per Location', fontsize='15')
plt.xlabel('Number of Active Hosts', fontsize='14')
plt.ylabel('Location', fontsize='14')

# Show the plot
plt.show()

# %% [markdown]
# Manhattan Dominates Host Numbers:
#
# Manhattan stands out as the leading borough with the highest number of hosts, boasting a significant count of 19,501.
# This indicates a robust presence of Airbnb hosts in the heart of New York City.
#
# Brooklyn Follows Closely:
#
# Brooklyn secures the second-highest position with a substantial 19,415 hosts.
# The competitive number in Brooklyn reflects a strong Airbnb hosting community, making it the second most popular borough for hosts.
#
# Queens Holds a Solid Position:
#
# Queens maintains a notable presence with 5,567 hosts, representing a considerable number of hosts but significantly lower than Manhattan and Brooklyn.
#
# Bronx Shows Moderate Participation:
#
# The Bronx features a moderate number of hosts, totaling 1,070. While not as high as Manhattan and Brooklyn, it contributes to the overall diversity of hosts in the city.
#
# Staten Island with Fewest Hosts:
#
# Staten Island has the smallest number of hosts, amounting to 365.
# This borough exhibits the fewest hosts among all five, indicating a relatively smaller Airbnb hosting community.
# Manhattan and Brooklyn Lead Significantly:
#
# Manhattan and Brooklyn collectively dominate the Airbnb hosting landscape, surpassing Queens and the Bronx by a substantial margin.
# The combined number of hosts in Manhattan and Brooklyn is more than double that of Queens and over 18 times higher than the Bronx.

# %% [markdown]
# ## 6.Find Total Counts of Each Room Types in entire NYC

# %%
Airbnb_df['room_type'].value_counts()
# Out:
# Entire home/apt    22784
# Private room       21996
# Shared room         1138
# Name: room_type, dtype: int64

# %%
#Visualize using countplot
sns.countplot(x="room_type",data=Airbnb_df)
# Out:
# <Axes: xlabel='room_type', ylabel='count'>

# %% [markdown]
# Observations:
#
# Predominance of Entire Home/Apt and Private Room:
#
# The majority of Airbnb listings in entire NYC fall into two main room types:
# "Entire home/apt" with 22,784 listings and "Private room" with 21,996 listings.
# Travelers have a diverse range of choices, primarily between having an entire home/apartment to themselves or opting for a private room within a shared space.
#
# Limited Availability of Shared Rooms:
# Shared rooms represent a smaller portion of the listings, totaling 1,138.
# The lower count of shared rooms suggests that this room type is less prevalent among Airbnb offerings in the entire NYC area.
#
# Preference for Private Spaces:
# The higher counts for "Entire home/apt" and "Private room" indicate a strong preference among travelers for private accommodations.
# This aligns with the desire for more personal space and privacy, influencing the popularity of these two room types.
#
# Diverse Accommodation Options:
# The variety in room types reflects the diverse needs and preferences of Airbnb users, allowing them to choose accommodations that suit their travel style and budget.
#
# Balanced Distribution:
# While "Entire home/apt" slightly outnumbers "Private room," the relatively close counts suggest a balanced distribution between these two prominent room types.
#
# Consideration for Shared Spaces:
# The presence of shared rooms, although less common, caters to travelers seeking budget-friendly options or those open to a communal living experience.

# %% [markdown]
# 7.Find Stay requirement counts by Minimum Nights

# %%
# Group the DataFrame by the minimum_nights column and count the number of rows in each group
min_nights_count = Airbnb_df.groupby('minimum_nights').size().reset_index(name = 'count')

# Sort the resulting DataFrame in descending order by the count column
min_nights_count = min_nights_count.sort_values('count', ascending=False)

# Select the top 10 rows
min_nights_count = min_nights_count.head(15)

# Reset the index
min_nights_count = min_nights_count.reset_index(drop=True)

# Display the resulting DataFrame
min_nights_count
# Out:
#     minimum_nights  count
# 0                1  12067
# 1                2  11080
# 2                3   7375
# 3               30   3489
# 4                4   3066
# 5                5   2821
# 6                7   1951
# 7                6    679
# 8               14    539
# 9               10    462
# 10              29    327
# 11              15    272
# 12              20    215
# 13              31    189
# 14              28    173

# %%
# Extract the minimum_nights and count columns from the DataFrame
minimum_nights = min_nights_count['minimum_nights']
count = min_nights_count['count']# Set the figure size
plt.figure(figsize=(12, 6))

# Create a horizontal bar chart
plt.barh(minimum_nights, count, color='salmon')

# Add axis labels and a title
plt.xlabel('Count', fontsize='14')
plt.ylabel('Minimum Nights', fontsize='14')
plt.title('Stay Requirement by Minimum Nights', fontsize='15')

# Show the plot
plt.show()

# %% [markdown]
# Observations -->
#
# The majority of listings on Airbnb have a minimum stay requirement of 1 or 2 nights, with 12067 and 11080 listings, respectively.
#
# The number of listings with a minimum stay requirement decreases as the length of stay increases, with 7375 listings requiring a minimum stay of 3 nights, and so on.
#
# There are relatively few listings with a minimum stay requirement of 30 nights or more, with 3489 and 189 listings, respectively.

# %% [markdown]
# ---
# **(8)Find the total number of reviews and maximum reviews by each Neighbourhood group**

# %%
#grouping by using aggregation function
reviews_summary = Airbnb_df.groupby('neighbourhood_group').agg({
    'total_reviews': ['sum', 'max']
}).reset_index()

# Rename the columns for clarity
reviews_summary.columns = ['neighbourhood_group', 'total_reviews', 'max_reviews']
reviews_summary = reviews_summary.sort_values(by='max_reviews', ascending=False)

# Print the result
print(reviews_summary)
# Out:
#   neighbourhood_group  total_reviews  max_reviews
# 3              Queens         155719          629
# 2           Manhattan         428128          607
# 1            Brooklyn         475936          488
# 4       Staten Island          11536          333
# 0               Bronx          28185          321

# %%
# Set the figure size
plt.figure(figsize=(12, 10))

# Plot a pie chart for total reviews
plt.subplot(1, 2, 1)
plt.pie(reviews_summary['total_reviews'], labels=reviews_summary['neighbourhood_group'], autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral', 'lightgreen', 'gold', 'lightcyan'])
plt.title('Distribution of Total Reviews by Neighbourhood Group')

# Plot a pie chart for maximum reviews
plt.subplot(1, 2, 2)
plt.pie(reviews_summary['max_reviews'], labels=reviews_summary['neighbourhood_group'], autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral', 'lightgreen', 'gold', 'lightcyan'])
plt.title('Distribution of Maximum Reviews by Neighbourhood Group')

# Adjust layout for better readability
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Observations:
#
# Brooklyn Dominates Total Reviews:
#
# Brooklyn leads in total reviews with  475936  showcasing a high level of guest engagement.
#
# Queens Stands Out in Maximum Reviews:
#
# Queens has the highest maximum reviews (629), indicating exceptional performance for specific listings.
#
# Manhattan Shows Robust Engagement:
#
# Manhattan follows Brooklyn closely in total reviews, highlighting a strong Airbnb community.
#
# Staten Island and Bronx with Moderate Engagement:
#
# Staten Island and the Bronx exhibit moderate levels of engagement, contributing to the city's diverse hosting landscape.
#
# Diversity in Review Counts:
#
# Varied review counts across neighborhoods emphasize the diverse experiences and popularity of listings in different parts of NYC.

# %% [markdown]
#  (9).Find the most reviewed room type in Neighbourhood groups per month

# %%
# Set the figure size
plt.figure(figsize=(12, 5))

# Create a boxen plot for reviews_per_month, grouped by room_type and colored by neighbourhood_group
sns.boxenplot(x='room_type', y='reviews_per_month', hue='neighbourhood_group', data=Airbnb_df, palette='Set1', dodge=True)

# Add axis labels and a title
plt.xlabel('Room Type', fontsize='14')
plt.ylabel('Reviews per Month', fontsize='14')
plt.title('Distribution of Reviews per Month by Room Type and Neighbourhood Group', fontsize='15')

# Show the plot
plt.show()

# %% [markdown]
# Observations:
#
# Private Room Dominates Reviews:
#
# Private rooms receive the highest number of reviews per month across all neighborhood groups, with Manhattan leading, particularly having more than 50 reviews/month.
#
# Manhattan Excels in Private Room Reviews:
#
# Within the Private room category, Manhattan stands out as the neighborhood group with the highest number of reviews, showcasing its popularity among guests.
#
# Entire Home/Apt Reviews in Manhattan & Queens:
#
# Entire homes/apartments receive the most reviews in Manhattan and Queens, highlighting the demand for this room type in these neighborhood groups.
#
# Limited Reviews for Shared Rooms:
#
# Shared rooms receive comparatively fewer reviews, with Staten Island and the Bronx having the lowest counts, indicating lower popularity for this room type.

# %% [markdown]
# 10. Find Best Location Listing/Property Location For Travelers and Hosts

# %%
# Group the data by neighborhood and calculate the average number of reviews
neighbourhood_avg_reviews = Airbnb_df.groupby("neighbourhood")["total_reviews"].mean()

# Create a new DataFrame with the average number of reviews for each neighborhood
neighbourhood_reviews = pd.DataFrame({"neighbourhood": neighbourhood_avg_reviews.index, "avg_reviews": neighbourhood_avg_reviews.values})

# Merge the average number of reviews data with the original DataFrame
df1 = Airbnb_df.merge(neighbourhood_reviews, on="neighbourhood")

import seaborn as sns
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(14, 8))

# Create a scatter plot using Seaborn
sns.scatterplot(data=df1, x='longitude', y='latitude', hue='avg_reviews', palette='viridis', size='avg_reviews', sizes=(20, 200), alpha=0.7)

# Add a title
plt.title('Average Airbnb Reviews by Neighborhoods in New York City', fontsize=15)

# Show the plot
plt.show()

# %%
# Visualize average price by neighborhood
plt.figure(figsize=(14, 8))
sns.barplot(x='neighbourhood_group', y='price', data=Airbnb_df, order=Airbnb_df.groupby('neighbourhood_group')['price'].mean().sort_values().index, palette='coolwarm')
plt.title('Average Price by Neighborhood Group')
plt.xlabel('Neighborhood Group')
plt.ylabel('Average Price')
plt.show()

# %%
# Visualize reviews per month by neighborhood
plt.figure(figsize=(14, 8))
sns.barplot(x='neighbourhood_group', y='reviews_per_month', data=Airbnb_df, order=Airbnb_df.groupby('neighbourhood_group')['reviews_per_month'].mean().sort_values().index, palette='magma')
plt.title('Average Reviews per Month by Neighborhood Group')
plt.xlabel('Neighborhood Group')
plt.ylabel('Average Reviews per Month')
plt.show()

# %%
# Visualize availability by neighborhood
plt.figure(figsize=(14, 8))
sns.barplot(x='neighbourhood_group', y='availability_365', data=Airbnb_df, order=Airbnb_df.groupby('neighbourhood_group')['availability_365'].mean().sort_values().index, palette='plasma')
plt.title('Average Availability by Neighborhood Group')
plt.xlabel('Neighborhood Group')
plt.ylabel('Average Availability (in days)')
plt.show()

# %% [markdown]
# Manhattan has the highest number of listings:
#
# Inference: Manhattan is a popular and well-represented area on Airbnb, offering a diverse range of accommodations. Travelers can find a variety of options to choose from.
#
# Manhattan has the highest average price:
#
# Inference: While Manhattan offers a large number of listings, it tends to be on the higher end in terms of pricing. Travelers looking for a more upscale or central location may find Manhattan suitable, but it may not be the most budget-friendly option.
#
# Queens has the highest reviews per month:
#
# Inference: Queens is well-received by travelers, as indicated by the high average number of reviews per month. This suggests that Queens could be an attractive and satisfying location for travelers, potentially offering a positive experience.
#
# Staten Island has the highest availability in days:
#
# Inference: Staten Island stands out for its high availability, indicating that hosts in this area may have more flexible booking options. Travelers looking for greater availability and potential last-minute bookings may find Staten Island appealing.
#
# Overall Recommendations for Travelers and Hosts:
#
# Travelers:
#
# If budget is a primary concern, exploring listings in Queens or Staten Island may be beneficial due to potentially lower prices and good traveler satisfaction.
# Travelers seeking a central and bustling experience may still consider Manhattan, despite higher prices.
#
# Hosts:
#
# Hosts in Manhattan may find the high demand advantageous but should be mindful of pricing competitively to attract guests.
# Hosts in Queens should emphasize the positive reviews they receive, as it is a strong selling point.
#
# General Considerations:
#
# Hosts in Staten Island may benefit from marketing their properties as having high availability, attracting travelers looking for flexibility.
# Ultimately, the "best" location depends on the specific preferences and priorities of both travelers and hosts. Travelers may prioritize affordability and positive experiences, while hosts may consider the balance between demand and competitive pricing.

# %% [markdown]
#  (11).Find price variations in NYC Neighborhood groups

# %%
# Boxplot to visualize price variations in NYC Neighborhood groups
plt.figure(figsize=(14, 8))
sns.boxplot(x='neighbourhood_group', y='price', data=Airbnb_df, order=Airbnb_df.groupby('neighbourhood_group')['price'].median().sort_values().index, palette='Set3')
plt.title('Price Variations in NYC Neighborhood Groups')
plt.xlabel('Neighborhood Group')
plt.ylabel('Price')
plt.yscale('log')  # Using log scale for better visualization as the price distribution is skewed
plt.show()

# %% [markdown]
# Observations:
#
# Manhattan's Premium Pricing:
#
# Accommodations in Manhattan exhibit a wide price range, showcasing it as the most expensive neighborhood in NYC. This suggests the presence of luxurious amenities and attractions that contribute to the higher cost.
#
# Attractions Driving Prices:
#
# The elevated prices in Manhattan are indicative of its numerous attractive amenities and tourist destinations. Travelers are drawn to this neighborhood due to its wealth of valuable experiences.
#
# Extended Stays in Manhattan:
#
# Given the high concentration of tourist attractions and efficient public transportation, travelers are likely to opt for longer stays in Manhattan. The allure of the neighborhood's offerings encourages visitors to spend more time exploring.

# %% [markdown]
# # Business Solutions
# 1.High Demand in Manhattan and Brooklyn: Manhattan and Brooklyn have the highest demand for Airbnb rentals, with a large number of listings. This makes them attractive areas for hosts to invest in property.
#
# 2.Manhattan's High Demand and Price: Manhattan's world-famous attractions contribute to its high demand and prices on Airbnb. Tourists are drawn to its parks, museums, iconic landmarks, and overall cultural appeal.
#
# 3.Brooklyn's Strategic Location: Brooklyn ranks second in listings with more affordable prices compared to Manhattan. Strategic neighborhoods like Williamsburg and Bedford Stuyvesant offer proximity to Manhattan, making them appealing for budget-conscious travelers.
#
# 4.Top Neighborhoods: Williamsburg, Bedford-Stuyvesant, Harlem, Bushwick, and the Upper West Side lead in listing counts, indicating strong demand for Airbnb rentals in these areas.
#
# 5.Pricing Dynamics: The average price is higher in Manhattan, suggesting lucrative opportunities for Airbnb rentals. However, high competition in Manhattan and Brooklyn emphasizes the need for strategic property investment.
#
# 6.Short-Term Stays Dominant: Airbnb rentals are primarily for short-term stays, with fewer listings requiring a minimum stay of 30 nights or more. Hosts should consider properties catering to shorter stays for higher occupancy.
#
# 7.Accommodation Options: Most listings are entire homes or private rooms, providing travelers with diverse options. Hosts may consider properties accommodating multiple guests.
#
# 8.Availability Variation Across Neighborhoods: Availability of Airbnb rentals varies significantly among neighborhoods. Hosts should consider neighborhoods with high demand but lower competition.
#
# 9.Competition Level: The market is competitive, with a small number of hosts dominating. Consider investing in areas with fewer listings to stand out and attract guests.
#
# 10.Airport Proximity in Queens: Neighborhoods near the airport in Queens likely have higher average reviews due to tourist traffic. Proximity to the airport makes these areas convenient for short-term stays with potentially lower costs compared to Manhattan and Brooklyn.

# %% [markdown]
# ---
#
# # **Thank You**
